# %% [markdown]
# # Introduction to Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot([1, 2, 3, 4]);

# %%
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]
plt.plot(x, y);

# %%
# 1st method
fig = plt.figure() # create a figure
ax = fig.add_subplot() # adds some axes
plt.show()

# %%
# 2nd method
fig = plt.figure() # creates a figure
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x,y) # add some data
plt.show()

# %%
# 3rd method (recommended)
fig, ax = plt.subplots()
ax.plot(x, [50, 100, 240, 490]); # add some data

# %% [markdown]
# ## Matplotlib example workflow

# %%
# 0. import matplotlib and get it ready for plotting in Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# 2. Setup plot
fig, ax = plt.subplots(figsize=(10, 10)) # (width, height)

# 3. Plot data
ax.plot(x, y)

# 4. Customize plot
ax.set(title="Simple Plot",
      xlabel="this is the x-axis",
      ylabel="this is the y-axis")

# 5. Save and show (save the whole figure)
fig.savefig("../data/images/sample-plot.png")

# %% [markdown]
# ## Making figuers with NumPy arrays
#
# Use:
# * Line plot
# * Scatter plot
# * Bar plot
# * Histogram
# * Subplots

# %%
import numpy as np

# %%
# Create some data
x = np.linspace(0,10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# Plat the data (line plot)
fig, ax = plt.subplots()
ax.plot(x, x**2)

# %%
# Use same daate to make a scatter plot
fix, ax = plt.subplots()
ax.scatter(x, np.exp(x))

# %%
# Another scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x))

# %%
# make a plot from a dictionary
nut_butter_prices = {"Almont Butter": 10,
                    "Peanut Butter": 8,
                    "Cashew Butter": 13}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax.set(title="Dan's Nut Butter Store", ylabel="Price ($)");

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()));

# %%
# Some data
x = np.random.randn(1000)
fig,ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ## Two options for subplots

# %%
# Subplot option 1
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                            ncols=2,
                                            figsize=(10,5))
# Plot to each different axis
ax1.plot(x, x/2)
ax2.scatter(np.random.random(10), np.random.random(10))
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax3.set(title="Nut Butter Chart", ylabel="Prices $")
ax4.hist(np.random.randn(111));

# %%
# Subplots option 2
fig, ax = plt.subplots(nrows=2,
                      ncols=2,
                      figsize=(10,5))
# Plot to each different index
ax[0,0].plot(x, x/2)
ax[0,1].scatter(np.random.random(10), np.random.random(10))
ax[1,0].bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax[1,1].hist(np.random.randn(111));

# %% [markdown]
# ## Plotting from pandas DataFrames

# %%
import pandas as pd
import numpy as np

# %%
# make DataFrame
car_sales = pd.read_csv("../data/car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),
              index=pd.date_range("1/1/2020", periods=1000))
ts = ts.cumsum()
ts.plot();

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
# Remove last two digits from price
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"] = pd.date_range("1/1/2020", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
car_sales["Price"] = car_sales["Price"].astype(int)
car_sales["Total Sales"] = car_sales["Price"].cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
# Find the most frequent car colours
colour_freq = car_sales["Colour"].value_counts().to_dict()
colour_freq
# Out:
# {'White': 4, 'Blue': 3, 'Green': 1, 'Black': 1, 'Red': 1}

# %%
fig,ax = plt.subplots()
ax.bar(colour_freq.keys(), colour_freq.values())
ax.set(title="Most Frequent Colours", ylabel="Colours");

# %%
# How about a bar graph?
x = np.random.rand(10, 4)
x
# Out:
# array([[0.99097887, 0.67611118, 0.11116321, 0.07504425],
#        [0.22293597, 0.83530559, 0.60907307, 0.89159275],
#        [0.05334421, 0.57485079, 0.30471182, 0.36701153],
#        [0.45847158, 0.43234803, 0.50267794, 0.60734591],
#        [0.07200374, 0.96848848, 0.79296461, 0.28112006],
#        [0.29775567, 0.93406075, 0.36646707, 0.2762551 ],
#        [0.41508178, 0.87376877, 0.92567494, 0.39327021],
#        [0.52574966, 0.18285727, 0.35192181, 0.47318864],
#        [0.92176486, 0.51400234, 0.16994335, 0.09534261],
#        [0.86274309, 0.26550338, 0.29690945, 0.37274761]])

# %%
# Turn it into a dataframe
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.990979  0.676111  0.111163  0.075044
# 1  0.222936  0.835306  0.609073  0.891593
# 2  0.053344  0.574851  0.304712  0.367012
# 3  0.458472  0.432348  0.502678  0.607346
# 4  0.072004  0.968488  0.792965  0.281120
# 5  0.297756  0.934061  0.366467  0.276255
# 6  0.415082  0.873769  0.925675  0.393270
# 7  0.525750  0.182857  0.351922  0.473189
# 8  0.921765  0.514002  0.169943  0.095343
# 9  0.862743  0.265503  0.296909  0.372748

# %%
df.plot.bar();

# %%
df.plot(kind="bar");

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
car_sales.plot(x="Make", y="Odometer (KM)", kind="bar");

# %%
# Histogram (spread of data)

car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
car_sales["Odometer (KM)"].plot.hist(bins=50);

# %%
# Exercise on another dataset
heart_disease = pd.read_csv("../data/heart-disease.csv")
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
# Create a histogram of age
heart_disease["age"].plot.hist(bins=35);

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist(figsize=(10,30), subplots=True);

# %% [markdown]
# ### Which method should you use (pyplot vs matplotlib OO method?)
#
# * when plotting quickly, it's okay to use the simpler pyplot API
# * when plotting something more advanced, use OO method

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50 = heart_disease[heart_disease["age"] > 50]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
len(over_50)
# Out:
# 208

# %%
# Pyplot method
over_50.plot(kind="scatter",
            x="age",
            y="chol",
            c="target");

# %%
fig, ax = plt.subplots(figsize=(10,6))
over_50.plot(kind="scatter",
            x="age",
            y="chol",
            c="target",
            ax=ax);

#ax.set_xlim([45, 100])

# %%
## OO method from scratch
fig, ax = plt.subplots(figsize=(10,6))

# Plot the data
scatter = ax.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c=over_50["target"])

# Customize
ax.set(title="Heart Disease and Cholesterol Levels",
      xlabel="Age",
      ylabel="Cholesterol")

# Add a legend
ax.legend(*scatter.legend_elements(), title="Target")

# Add a horizontal line
ax.axhline(over_50["chol"].mean(),
                  linestyle="--");

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# Subplot of chol, age, thalach
fig, (ax0, ax1) = plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10,10),
                              sharex=True)

# Add data to ax0
scatter = ax0.scatter(x=over_50["age"],
                      y=over_50["chol"],
                      c=over_50["target"])

# Customize ax0
ax0.set(title="Heart Disease and Cholestorol Levels",
        ylabel="Cholesterol")
# Add a legend
ax0.legend(*scatter.legend_elements(), title="Target")
# Add a meanline
ax0.axhline(y=over_50["chol"].mean(),
            linestyle="--")

# ax1 subplot with thalach
scatter = ax1.scatter(x=over_50["age"],
                      y=over_50["thalach"],
                      c=over_50["target"])
ax1.set(title="Heart Disease and Max Heart Rate",
        xlabel="Age",
        ylabel="Max Heart Rate")
ax1.legend(*scatter.legend_elements(), title="Target")
ax1.axhline(y=over_50["thalach"].mean(),
            linestyle="--");

# Add a title to the figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold");

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
fig, ax = plt.subplots(figsize=(10,6))
hist = ax.hist(x=over_50["trestbps"],
               bins=18,
               color="orange",
               alpha=0.75)
ax.set(title="Resting Blood Pressure",
       xlabel="Resting Blood Pressure (bps)",
       ylabel="Patients");

# %% [markdown]
# ## Customizing Matplotlib

# %%
# See the different styles
plt.style.available
# Out:
# ['bmh',
#  'seaborn-dark-palette',
#  'seaborn-talk',
#  'seaborn-colorblind',
#  'seaborn-notebook',
#  'ggplot',
#  'seaborn-paper',
#  'seaborn-muted',
#  'seaborn-ticks',
#  'classic',
#  'seaborn-bright',
#  'seaborn-white',
#  'fast',
#  'tableau-colorblind10',
#  'seaborn',
#  'grayscale',
#  'dark_background',
#  'seaborn-whitegrid',
#  'seaborn-poster',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  '_classic_test',
#  'fivethirtyeight',
#  'Solarize_Light2',
#  'seaborn-pastel',
#  'seaborn-deep']

# %%
# default style
car_sales["Price"].plot()

# %%
plt.style.use('seaborn-whitegrid')
car_sales["Price"].plot()

# %%
plt.style.use('seaborn')
car_sales["Price"].plot()

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
plt.style.use('ggplot')
car_sales["Price"].plot();

# %%
# Create some dummy data
x = np.random.randn(10, 4)
x
# Out:
# array([[ 1.11184868, -0.43687466, -0.32487124,  0.56583742],
#        [-0.12966629,  0.10878922,  0.3791646 ,  0.87491288],
#        [ 0.95334888, -0.13964638,  0.71982889, -0.959512  ],
#        [-0.29624793,  2.22987093, -0.18214566,  2.1695416 ],
#        [-0.7948327 , -1.9080476 ,  1.42589214,  0.11273144],
#        [-0.20178667,  1.3860723 , -1.87353275,  1.44031043],
#        [-2.76318573, -0.71469558,  0.67577537,  0.65622747],
#        [ 0.55854498, -1.00087626, -0.00960841,  1.51406936],
#        [-1.36265684,  1.02726201, -0.39397058, -1.23572596],
#        [ 1.99398926,  0.53235581,  1.14110929,  0.71305789]])

# %%
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  1.111849 -0.436875 -0.324871  0.565837
# 1 -0.129666  0.108789  0.379165  0.874913
# 2  0.953349 -0.139646  0.719829 -0.959512
# 3 -0.296248  2.229871 -0.182146  2.169542
# 4 -0.794833 -1.908048  1.425892  0.112731
# 5 -0.201787  1.386072 -1.873533  1.440310
# 6 -2.763186 -0.714696  0.675775  0.656227
# 7  0.558545 -1.000876 -0.009608  1.514069
# 8 -1.362657  1.027262 -0.393971 -1.235726
# 9  1.993989  0.532356  1.141109  0.713058

# %%
ax = df.plot(kind='bar')

# %%
# customize plot with set() method
ax = df.plot(kind='bar')
ax.set(title='Random Bar Graph',
       xlabel='Row Number',
       ylabel='Random Number')
# Make legend visible
ax.legend().set_visible(True);

# %%
# change style
plt.style.use('seaborn-whitegrid')

# Subplot of chol, age, thalach
fig, (ax0, ax1) = plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10,10),
                              sharex=True)

# Add data to ax0
scatter = ax0.scatter(x=over_50["age"],
                      y=over_50["chol"],
                      c=over_50["target"],
                      cmap="winter") # change color style

# Customize ax0
ax0.set_xlim([50,80])
ax0.set(title="Heart Disease and Cholestorol Levels",
        ylabel="Cholesterol")
# Add a legend
ax0.legend(*scatter.legend_elements(), title="Target")
# Add a meanline
ax0.axhline(y=over_50["chol"].mean(),
            linestyle="--")

# ax1 subplot with thalach
scatter = ax1.scatter(x=over_50["age"],
                      y=over_50["thalach"],
                      c=over_50["target"],
                      cmap="winter")
ax1.set_ylim([60,200])
ax1.set(title="Heart Disease and Max Heart Rate",
        xlabel="Age",
        ylabel="Max Heart Rate")
ax1.legend(*scatter.legend_elements(), title="Target")
ax1.axhline(y=over_50["thalach"].mean(),
            linestyle="--");

# Add a title to the figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold");

# %% [markdown]
# # How to share the data

# %%
fig

# %%
fig.savefig("../data/images/heart-disease-analysis-plot-saved-fig.png")

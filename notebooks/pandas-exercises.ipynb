# %% [markdown]
# # Prandas Practice
#
# This notebook is dedicated to practicing different tasks with pandas. The solutions are avilable in a solutions notebook, however you should always try to figure them out yourself first.
#
# It should be noted there may be more than one different way to answer a question or complete an exercise.
#
# Exercises are based off (and directly taken from) the quick introduction to pandas notebook.
#
# Different tasks will be detailed by comments or text.
#
# For further reference and resources, it's advised to check out the [pandas documnetation](https://pandas.pydata.org/pandas-docs/stable/).

# %%
# Import pandas
import pandas as pd

# %%
# Create a series of three different colours
colours = pd.Series(["Red", "Blue", "Yellow"])

# %%
# View the series of different colours
colours
# Out:
# 0       Red
# 1      Blue
# 2    Yellow
# dtype: object

# %%
# Create a series of three different car types and view it
cars = pd.Series(["Mercedes", "VW", "Honda"])
cars
# Out:
# 0    Mercedes
# 1          VW
# 2       Honda
# dtype: object

# %%
# Combine the Series of cars and colours into a DataFrame
cars_df = pd.DataFrame({"Car Make": cars, "Colour": colours})
cars_df
# Out:
#    Car Make  Colour
# 0  Mercedes     Red
# 1        VW    Blue
# 2     Honda  Yellow

# %%
# Import "../data/car-sales.csv" and turn it into a DataFrame
car_sales = pd.read_csv("../data/car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# **Note:** Since you've imported `../data/car-sales.csv` as a DataFrame, we'll now refer to this DataFrame as 'the car sales DataFrame'.

# %%
# Export the DataFrame you created to a .csv file
car_sales.to_csv("../data/car_sales_exported.csv", index=False)
car_sales_exported = pd.read_csv("../data/car_sales_exported.csv")
car_sales_exported
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Find the different datatypes of the car data DataFrame
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
# Describe your current car sales DataFrame using describe()
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
# Get information about your DataFrame using info()
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %% [markdown]
# What does it show you?

# %%
# Create a Series of different numbers and find the mean of them
nums = pd.Series([2.4884, 0.3908, 888.3982, 3091.28, 21.554, 3.808])
nums.mean()
# Out:
# 667.9865666666667

# %%
# Create a Series of different numbers and find the sum of them
nums.sum()
# Out:
# 4007.9194

# %%
# List out all the column names of the car sales DataFrame
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
# Find the length of the car sales DataFrame
len(car_sales)
# Out:
# 10

# %%
# Show the first 5 rows of the car sales DataFrame
car_sales.head(5)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
# Show the first 7 rows of the car sales DataFrame
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
# Show the bottom 5 rows of the car sales DataFrame
car_sales.tail(5)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# Use .loc to select the row at index 3 of the car sales DataFrame
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# Use .iloc to select the row at position 3 of the car sales DataFrame
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %% [markdown]
# Notice how they're the same? Why do you think this is?
#
# Check the pandas documentation for [.loc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html) and [.iloc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html). Think about a different situation each could be used for and try them out.

# %%
# Select the "Odometer (KM)" column from the car sales DataFrame
odometer = car_sales["Odometer (KM)"]
odometer
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
# Find the mean of the "Odometer (KM)" column in the car sales DataFrame
odometer.mean()
# Out:
# 78601.4

# %%
# Select the rows with over 100,000 kilometers on the Odometer
odometer_gt_100_000 = odometer[odometer > 100000]
odometer_gt_100_000
# Out:
# 0    150043
# 4    213095
# Name: Odometer (KM), dtype: int64

# %%
# Create a crosstab of the Make and Doors columns
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Group columns of the car sales DataFrame by the Make column and find the average
car_sales.groupby("Make").mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# Import Matplotlib and create a plot of the Odometer column
# Don't forget to use %matplotlib inline
# %matplotlib inline
odometer.plot()

# %%
# Create a histogram of the Odometer column using hist()
odometer.hist()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Try to plot the Price column using plot()
# car sales prices as integer, without cents
car_sales_price = car_sales["Price"].str.replace('[\$\,\.]','').astype(int)
car_sales_price.plot()

# %% [markdown]
# Why didn't it work? Can you think of a solution?
#
# You might want to search for "how to convert a pandas string columb to numbers".
#
# And if you're still stuck, check out this [Stack Overflow question and answer on turning a price column into integers](https://stackoverflow.com/questions/44469313/price-column-object-to-int-in-pandas).
#
# See how you can provide the example code there to the problem here.

# %%
# Remove the punctuation from price column
car_sales_price_without_cents = car_sales["Price"].str.replace('[\$\,]|\.\d*', '').astype(int)
car_sales_price_without_cents
# Out:
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: int64

# %%
# Check the changes to the price column
car_sales["Price"] = car_sales_price_without_cents
car_sales["Price"].dtype
# Out:
# dtype('int64')

# %%
# Remove the two extra zeros at the end of the price column

# %%
# Check the changes to the Price column

# %%
# Change the datatype of the Price column to integers

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
# Lower the strings of the Make column
car_sales["Make"].str.lower()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %% [markdown]
# If you check the car sales DataFrame, you'll notice the Make column hasn't been lowered.
#
# How could you make these changes permanent?
#
# Try it out.

# %%
# Make lowering the case of the Make column permanent
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
# Check the car sales DataFrame
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %% [markdown]
# Notice how the Make column stays lowered after reassigning.
#
# Now let's deal with missing data.

# %%
# Import the car sales DataFrame with missing data ("../data/car-sales-missing-data.csv")
car_sales_md = pd.read_csv("../data/car-sales-extended-missing-data.csv")

# Check out the new DataFrame
car_sales_md
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %% [markdown]
# Notice the missing values are represented as `NaN` in pandas DataFrames.
#
# Let's try fill them.

# %%
# check which columns have null values
null_columns = car_sales_md.columns[car_sales_md.isnull().any()]
null_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
# count null columns
car_sales_md[null_columns].isnull().sum()
# Out:
# Make             49
# Colour           50
# Odometer (KM)    50
# Doors            50
# Price            50
# dtype: int64

# %%
# select all columns with missing data (null values)
car_sales_md[car_sales_md.isnull().any(axis=1)][null_columns]
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 7     Honda  White            NaN    4.0  20306.0
# 8       NaN  White       130538.0    4.0   9374.0
# 13      NaN  White       134181.0    4.0  11121.0
# 20   Toyota    NaN       124844.0    4.0  24130.0
# 21    Honda    NaN        30615.0    4.0  29653.0
# ..      ...    ...            ...    ...      ...
# 974     NaN  White       155383.0    4.0  14345.0
# 975   Honda    NaN        22409.0    4.0  10429.0
# 983  Toyota    Red            NaN    4.0  14671.0
# 985     NaN   Blue       216250.0    4.0   9691.0
# 996     NaN  White       155144.0    3.0   5716.0
#
# [227 rows x 5 columns]

# %%
# Fill the Odometer (KM) column missing values with the mean of the column inplace
odo_km = car_sales_md["Odometer (KM)"]
odo_km.fillna(odo_km.mean(), inplace=True)
# check if there are null columns in Odometer (KM)
odo_km.isnull().any()
# Out:
# False

# %%
# Remove the rest of the missing data inplace
car_sales_md.dropna(inplace=True)

# %%
car_sales_md
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 994     BMW   Blue       163322.0    3.0  31666.0
# 995  Toyota  Black        35820.0    4.0  32042.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [815 rows x 5 columns]

# %%
# Verify the missing values are removed by viewing the DataFrame
car_sales_md.isnull().any()
# Out:
# Make             False
# Colour           False
# Odometer (KM)    False
# Doors            False
# Price            False
# dtype: bool

# %% [markdown]
# We'll now start to add columns to our DataFrame.

# %%
# Create a "Seats" column where every row has a value of 5
car_sales_md["Seats"] = 5
car_sales_md
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats
# 0     Honda  White        35431.0    4.0  15323.0      5
# 1       BMW   Blue       192714.0    5.0  19943.0      5
# 2     Honda  White        84714.0    4.0  28343.0      5
# 3    Toyota  White       154365.0    4.0  13434.0      5
# 4    Nissan   Blue       181577.0    3.0  14043.0      5
# ..      ...    ...            ...    ...      ...    ...
# 994     BMW   Blue       163322.0    3.0  31666.0      5
# 995  Toyota  Black        35820.0    4.0  32042.0      5
# 997  Nissan   Blue        66604.0    4.0  31570.0      5
# 998   Honda  White       215883.0    4.0   4001.0      5
# 999  Toyota   Blue       248360.0    4.0  12732.0      5
#
# [815 rows x 6 columns]

# %%
# Create a column called "Engine Size" with random values between 1.3 and 4.5
# Remember: If you're doing it from a Python list, the list has to be the same length
# as the DataFrame
import numpy as np
car_sales_md["Engine Size"] = np.random.uniform(1.3, 4.5, car_sales_md.shape[0])
car_sales_md["Engine Size"]
# Out:
# 0      3.423912
# 1      2.027979
# 2      3.699109
# 3      2.685559
# 4      1.492315
#          ...
# 994    2.352820
# 995    2.986377
# 997    1.420158
# 998    3.123006
# 999    3.959834
# Name: Engine Size, Length: 815, dtype: float64

# %%
# Create a column which represents the price of a car per kilometer
# Then view the DataFrame
car_sales_md["Price/km"] = car_sales_md["Price"] / car_sales_md["Odometer (KM)"]
car_sales_md
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats  Engine Size  \
# 0     Honda  White        35431.0    4.0  15323.0      5     3.423912
# 1       BMW   Blue       192714.0    5.0  19943.0      5     2.027979
# 2     Honda  White        84714.0    4.0  28343.0      5     3.699109
# 3    Toyota  White       154365.0    4.0  13434.0      5     2.685559
# 4    Nissan   Blue       181577.0    3.0  14043.0      5     1.492315
# ..      ...    ...            ...    ...      ...    ...          ...
# 994     BMW   Blue       163322.0    3.0  31666.0      5     2.352820
# 995  Toyota  Black        35820.0    4.0  32042.0      5     2.986377
# 997  Nissan   Blue        66604.0    4.0  31570.0      5     1.420158
# 998   Honda  White       215883.0    4.0   4001.0      5     3.123006
# 999  Toyota   Blue       248360.0    4.0  12732.0      5     3.959834
#
#      Price/km
# 0    0.432474
# 1    0.103485
# 2    0.334573
# 3    0.087027
# 4    0.077339
# ..        ...
# 994  0.193887
# ...

# %%
# Remove the last column you added using .drop()
car_sales_md = car_sales_md.drop("Price/km", axis = 1)
car_sales_md
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats  Engine Size
# 0     Honda  White        35431.0    4.0  15323.0      5     3.423912
# 1       BMW   Blue       192714.0    5.0  19943.0      5     2.027979
# 2     Honda  White        84714.0    4.0  28343.0      5     3.699109
# 3    Toyota  White       154365.0    4.0  13434.0      5     2.685559
# 4    Nissan   Blue       181577.0    3.0  14043.0      5     1.492315
# ..      ...    ...            ...    ...      ...    ...          ...
# 994     BMW   Blue       163322.0    3.0  31666.0      5     2.352820
# 995  Toyota  Black        35820.0    4.0  32042.0      5     2.986377
# 997  Nissan   Blue        66604.0    4.0  31570.0      5     1.420158
# 998   Honda  White       215883.0    4.0   4001.0      5     3.123006
# 999  Toyota   Blue       248360.0    4.0  12732.0      5     3.959834
#
# [815 rows x 7 columns]

# %%
# Shuffle the DataFrame using sample() with the frac parameter set to 1
# Save the the shuffled DataFrame to a new variable
car_sales_shuffled = car_sales_md.sample(frac=1)
car_sales_shuffled
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats  Engine Size
# 430  Nissan   Blue   45668.000000    4.0  13310.0      5     2.002801
# 866     BMW  White  118286.000000    5.0  14145.0      5     1.386387
# 3    Toyota  White  154365.000000    4.0  13434.0      5     2.685559
# 18   Nissan  White   67991.000000    3.0   9109.0      5     1.319447
# 802   Honda  White  192655.000000    4.0  12609.0      5     3.951990
# ..      ...    ...            ...    ...      ...    ...          ...
# 476  Toyota  White  185742.000000    4.0  16865.0      5     2.083750
# 380  Nissan   Blue   76412.000000    4.0  13492.0      5     3.290976
# 482  Nissan  White   51004.000000    4.0  31633.0      5     2.723219
# 556   Honda  White   95579.000000    4.0  11135.0      5     4.020997
# 513  Toyota   Blue  131253.237895    4.0  13213.0      5     4.010933
#
# [815 rows x 7 columns]

# %% [markdown]
# Notice how the index numbers get moved around. The [`sample()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html) function is a great way to get random samples from your DataFrame. It's also another great way to shuffle the rows by setting `frac=1`.

# %%
# Reset the indexes of the shuffled DataFrame
car_sales_shuffled.reset_index(drop=True, inplace=True)
car_sales_shuffled
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats  Engine Size
# 0    Nissan   Blue   45668.000000    4.0  13310.0      5     2.002801
# 1       BMW  White  118286.000000    5.0  14145.0      5     1.386387
# 2    Toyota  White  154365.000000    4.0  13434.0      5     2.685559
# 3    Nissan  White   67991.000000    3.0   9109.0      5     1.319447
# 4     Honda  White  192655.000000    4.0  12609.0      5     3.951990
# ..      ...    ...            ...    ...      ...    ...          ...
# 810  Toyota  White  185742.000000    4.0  16865.0      5     2.083750
# 811  Nissan   Blue   76412.000000    4.0  13492.0      5     3.290976
# 812  Nissan  White   51004.000000    4.0  31633.0      5     2.723219
# 813   Honda  White   95579.000000    4.0  11135.0      5     4.020997
# 814  Toyota   Blue  131253.237895    4.0  13213.0      5     4.010933
#
# [815 rows x 7 columns]

# %% [markdown]
# Notice the index numbers have been changed to have order (start from 0).

# %%
# Change the Odometer values from kilometers to miles using a Lambda function
# Then view the DataFrame
car_sales_shuffled["Odometer (KM)"] = car_sales_shuffled["Odometer (KM)"].apply(lambda x: x / 1.6)
car_sales_shuffled
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats  Engine Size
# 0    Nissan   Blue   28542.500000    4.0  13310.0      5     2.002801
# 1       BMW  White   73928.750000    5.0  14145.0      5     1.386387
# 2    Toyota  White   96478.125000    4.0  13434.0      5     2.685559
# 3    Nissan  White   42494.375000    3.0   9109.0      5     1.319447
# 4     Honda  White  120409.375000    4.0  12609.0      5     3.951990
# ..      ...    ...            ...    ...      ...    ...          ...
# 810  Toyota  White  116088.750000    4.0  16865.0      5     2.083750
# 811  Nissan   Blue   47757.500000    4.0  13492.0      5     3.290976
# 812  Nissan  White   31877.500000    4.0  31633.0      5     2.723219
# 813   Honda  White   59736.875000    4.0  11135.0      5     4.020997
# 814  Toyota   Blue   82033.273684    4.0  13213.0      5     4.010933
#
# [815 rows x 7 columns]

# %%
# Change the title of the Odometer (KM) to repsent miles instead of kilometers
car_sales_shuffled.rename(columns={"Odometer (KM)" : "Odometer (M)"}, inplace=True)
car_sales_shuffled
# Out:
#        Make Colour   Odometer (M)  Doors    Price  Seats  Engine Size
# 0    Nissan   Blue   28542.500000    4.0  13310.0      5     2.002801
# 1       BMW  White   73928.750000    5.0  14145.0      5     1.386387
# 2    Toyota  White   96478.125000    4.0  13434.0      5     2.685559
# 3    Nissan  White   42494.375000    3.0   9109.0      5     1.319447
# 4     Honda  White  120409.375000    4.0  12609.0      5     3.951990
# ..      ...    ...            ...    ...      ...    ...          ...
# 810  Toyota  White  116088.750000    4.0  16865.0      5     2.083750
# 811  Nissan   Blue   47757.500000    4.0  13492.0      5     3.290976
# 812  Nissan  White   31877.500000    4.0  31633.0      5     2.723219
# 813   Honda  White   59736.875000    4.0  11135.0      5     4.020997
# 814  Toyota   Blue   82033.273684    4.0  13213.0      5     4.010933
#
# [815 rows x 7 columns]

# %% [markdown]
# ##### Extensions
#
# For more exercises, check out the pandas documentation, partiuclarly the [10-minutes to pandas section](https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html).
#
# One great exercise would be to retype out the entire section into a Jupyter Notebook of your own.
#
# Get hands-on with the code and see what it does.
#
# The next place you should check out are the [top questions and answers on Stack Overflow for pandas](https://stackoverflow.com/questions/tagged/pandas?sort=MostVotes&edited=true). Often, these contain some of the most useful and common pandas functions. Be sure to play around with the different filters!
#
# Finally, always remember, the best way to learn something new to is try it. Make mistakes. Ask questions, get things wrong, take note of the things you do most often. And don't worry if you keep making the same mistake, pandas has many ways to do the same thing and is a big library. So it'll likely take a while before you get the hang of it.
